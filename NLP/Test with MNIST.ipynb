# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=False)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
train_X = mnist.train.images.reshape((-1, 28, 28, 1))
# train_X = mnist.train.images.reshape((-1, 784))
train_y = mnist.train.labels

# %%
train_y.shape
# Out:
# (55000,)

# %%
import tensorflow as tf
from hedgeable_ai.models.nn.rnn import RNNModel
from hedgeable_ai.models.nn.ff import MLPModel
from hedgeable_ai.functions.classification.nn import NNClassifier

conf = {"model":[
            {"name": "conv2d", "kernel_size":(3, 3), "num_filter":32, "stride":1,
             "padding": 'SAME', "is_batch":False, 'activation': tf.nn.relu},
            {"name": "conv2d", "kernel_size":(3, 3), "num_filter":64,"stride":1,
             "padding": 'SAME', "is_batch":False, 'activation': tf.nn.relu},
            {"name": "pooling", "window_shape":(2, 2), "strides":(2, 2),
            "pooling_type": "MAX", "padding": 'SAME'},
            {"name": "dense", "is_flatten":True, "is_batch":False, "num_hidden": 128, 'activation': tf.nn.relu},
        ],
        "learning_rate": 1e-2,
        "learning_rate_decay_step": 10,
        "learning_rate_decay": 0.9,
        "learning_rate_minimum": 1e-2,
        "batch_size":512,
       }
"""
conf = {"model":[
        ],
        "learning_rate": 0.05,
        "learning_rate_decay_step": 10,
        "learning_rate_decay": 0.9,
        "learning_rate_minimum": 0.05,
        "batch_size":128,
       }
"""

tf.reset_default_graph()
model = MLPModel
model = NNClassifier((28, 28, 1), 10, model, conf=conf, is_sequence=False)
model.train(train_X, train_y, num_epochs=100, batch_log_freq=None, is_processed=True, 
            batch_bar=True, is_memory_intensive=False)
# Out:
# /home/tomoaki/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/tomoaki/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# /home/tomoaki/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_inspect.py:45: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   if d.decorator_argspec is not None), _inspect.getargspec(target))
# ...

# %%
train = tf.train.AdadeltaOptimizer()

# %%
train.compute_gradients
# Out:
# array([[ 0.07181758,  0.14862165,  0.12537505, ...,  0.09188624,
#          0.06741022,  0.08037698],
#        [ 0.08911183,  0.12802683,  0.075929  , ...,  0.12667018,
#          0.09118815,  0.08746417],
#        [ 0.08704653,  0.08773389,  0.08619919, ...,  0.1256336 ,
#          0.08735074,  0.12676969],
#        ...,
#        [ 0.11415634,  0.14945827,  0.07605509, ...,  0.09277792,
#          0.10303106,  0.07785366],
#        [ 0.08471462,  0.16553874,  0.08482523, ...,  0.087378  ,
#          0.10605861,  0.08809923],
#        [ 0.12177704,  0.12096165,  0.11964859, ...,  0.07878033,
#          0.10845225,  0.0751214 ]], dtype=float32)
