# %% [markdown]
# # Alternative Data Classification
# ##  Data Produced by individuals
# * From social media(e.g., Twitter, Facebook)
# * From specialized sites(e.g., Yelp, Amason)
# * Web search and personalized data(e.g., Google Trends)
#
# ## Data generated by Business Processes
# * Credit card transactions
# * E-commerce transactions
#
# ## Datat generated by sensors
# * Satelite images

# %% [markdown]
# # Regime
# ## Risk Premium Strategy
# * Look at regime evector space
# * Pick the close K points
# * Take average resturns and rank stocks

# %% [markdown]
# # Fundamental Analysis
# * Earnings per Share(EPS)
# * Price to Earnings Ratio(P/E)
# * Projected Earnings Growth(PEG)
# * Price to Sales Ratio(P/S)
# * Price to Book Ratio(P/B)
# * Dividend Payout Ratio
# * Dividend Yield
# * Return on Equity

# %%
x
# Out:
# [4, 5]
